# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
plt.style.use('ggplot')

# %%
df = pd.read_csv("Bike-Sharing-Dataset/day.csv")
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
df.corr()['cnt'].sort_values(ascending=False)
# Out:
# cnt           1.000000
# registered    0.945517
# casual        0.672804
# atemp         0.631066
# instant       0.628830
# temp          0.627494
# yr            0.566710
# season        0.406100
# mnth          0.279977
# weekday       0.067443
# workingday    0.061156
# holiday      -0.068348
# hum          -0.100659
# windspeed    -0.234545
# weathersit   -0.297391
# Name: cnt, dtype: float64

# %%
plt.scatter(df.temp, df.cnt)
plt.show()

# %%
df.casual.describe(), df.registered.describe()
# Out:
# (count     731.000000
#  mean      848.176471
#  std       686.622488
#  min         2.000000
#  25%       315.500000
#  50%       713.000000
#  75%      1096.000000
#  max      3410.000000
#  Name: casual, dtype: float64, count     731.000000
#  mean     3656.172367
#  std      1560.256377
#  min        20.000000
#  25%      2497.000000
#  50%      3662.000000
#  75%      4776.500000
#  max      6946.000000
#  Name: registered, dtype: float64)

# %%
spr = df[df['season']<=4]
plt.figure(figsize=(14,6))
plt.xticks([])
plt.xlabel('Days')
plt.scatter(spr.dteday, spr.cnt);

# %%
su
