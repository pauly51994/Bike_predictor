# %% [markdown]
# # Creating the final model

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
import scipy as sp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import datetime as dt

plt.style.use('seaborn')
sns.set(style="white")

# %%
df = pd.read_pickle('Residuals_df')

# %% [markdown]
# #### Creating interaction terms dataframe

# %%
interms = df.copy() # copy the df to not mess up original data

# dropping columns that should not interact
interms = interms.drop(['dteday','season','yr','mnth','weekday','atemp','weathersit','casual',
                        'registered','cnt','weather','resids','predictions'],axis=1)

# %%
# using PolynomialFeatures to interact everything in the interms df
poly1 = PolynomialFeatures(3)
poly_data = poly1.fit_transform(interms)
poly_columns = poly1.get_feature_names(list(interms.columns))
poly_features = pd.DataFrame(poly_data, columns=poly_columns, index=interms.index)

# %% [markdown]
#  - Cleaning up the interaction terms df

# %%
new_cols = list(poly_features.columns)

# getting rid of the columns that were interacted with themselves (i.e.  df['temp^2'])
poly_features = poly_features.drop([name for name in new_cols if '^' in name],axis=1)

# getting rid of all columns that were only 0 values
# this essentially got rid of all columns where a season interacted with another season, which doesn't make sense
poly_features = poly_features.loc[:, (poly_features != 0).any(axis=0)]

# %% [markdown]
# #### Final dataframe to use for model

# %%
# combining the original dataframe with the interaction terms dataframe
final_df = pd.concat([df, poly_features],axis=1)

# making column names usable by replacing empty space with underscores(_)
final_df.columns = [name.replace(' ','_') for name in final_df.columns]

# getting rid of any duplicate columns that were made in the combining process
final_df = final_df.loc[:,~final_df.columns.duplicated()]

# %% [markdown]
# #### Cleaning up the final dataframe

# %% [markdown]
# Drop certain interactions because these variables were unnecessary:
#  - winter and light_storm since they are categorical and part of the final analysis

# %%
columns_to_drop = ['dteday', 'instant', 'winter', 'light_storm', 'weekday', 'yr',
                   'mnth', 'weathersit', 'atemp', 'cnt', 'casual', 'registered', 'windspeed']

# %%
# Removes variables that interact with themselves
for col in columns_to_drop:
    final_df = final_df.drop([name for name in list(final_df.columns) if f'{col}' in name],axis=1)

# %%
final_df= final_df.select_dtypes(exclude=['object']) # Removing strings as values from the DF

# %% [markdown]
# Choosing which variables to place in our model

# %%
# Creating a string of independent variables for OLS model
workingivs = list(final_df.columns)

# Removed dependent variables from the workingivs list
workingivs.remove('resids')
workingivs.remove('predictions')

# String for input in OLS
IVs = ''.join(name+'+' for name in workingivs).strip('+')

# Running the original model
lr_model = ols(formula=f'resids~{IVs}', data=final_df).fit()
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 resids   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     27.63
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):          4.02e-159
# Time:                        14:13:56   Log-Likelihood:                -5839.6
# No. Observations:                 730   AIC:                         1.184e+04
# Df Residuals:                     652   BIC:                         1.219e+04
# Df Model:                          77
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept               -2.499e+04   3.02e+04     -0.828      0.408   -8.42e+04    3.42e+04
# clear                    2.519e+04   3.02e+04      0.835      0.404    -3.4e+04    8.44e+04
# fall                     1.875e+04   3.46e+04      0.541      0.589   -4.93e+04    8.68e+04
# holiday                  1763.9308   6455.615      0.273      0.785   -1.09e+04    1.44e+04
# hum                      2.807e+04   4.76e+04      0.590      0.556   -6.54e+04    1.22e+05
# misty                    2.118e+04   3.01e+04      0.703      0.483    -3.8e+04    8.04e+04
# hum_misty_workingday     1683.5349   8586.256      0.196      0.845   -1.52e+04    1.85e+04
# hum_spring_temp         -8484.5405   7583.388     -1.119      0.264   -2.34e+04    6406.269
# hum_spring_workingday     638.6243   1971.867      0.324      0.746   -3233.352    4510.600
# hum_summer_temp           1.95e+04   1.48e+04      1.319      0.188   -9531.217    4.85e+04
# hum_summer_workingday    1525.3791   3063.950      0.498      0.619   -4491.021    7541.779
# hum_temp_workingday      2622.7661   5958.021      0.440      0.660   -9076.459    1.43e+04
# misty_spring_temp       -3.607e+04   4.05e+04     -0.892      0.373   -1.16e+05    4.34e+04
# misty_spring_workingday -1.462e+04   5262.306     -2.778      0.006    -2.5e+04   -4288.026
# misty_summer_temp       -6314.4839   4424.302     -1.427      0.154    -1.5e+04    2373.115
# misty_summer_workingday -1410.1547    751.429     -1.877      0.061   -2885.668      65.358
# misty_temp_workingday    2.022e+04   5.06e+04      0.400      0.689   -7.91e+04     1.2e+05
# spring_temp_workingday  -3314.9421   2132.666     -1.554      0.121   -7502.665     872.780
# summer_temp_workingday   3500.6395   2776.674      1.261      0.208   -1951.662    8952.941
# ==============================================================================
# Omnibus:                      152.193   Durbin-Watson:                   1.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              438.788
# Skew:                          -1.025   Prob(JB):                     5.23e-96
# Kurtosis:                       6.197   Cond. No.                     1.77e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.16e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Cleaning up our model

# %% [markdown]
# Cutting down the variables based on pvalues

# %%
def refine_model(model, old_ivs, pval):
    """
    Checks p-value for each independent variable and removes the variables having p-value above (pval) threshold
    """
    pdf = pd.DataFrame(model.pvalues, columns=['pvalue'])        # Creating a p-value DF
    removers = list(pdf[pdf['pvalue']>pval].transpose().columns) # List of variables to remove
    new_ivs = [iv for iv in old_ivs if iv not in removers]       # Updated list of independent variables
    IVs = ''.join(name+'+' for name in new_ivs).strip('+')       # Creates string for input in OLS model
    
    # Prints the count of variables
    print(len(new_ivs))
    
    # Creates the new model
    new_model = ols(formula=f'resids~{IVs}', data=final_df).fit()
    
    # Returning the new model, list of remaining IVs, new max p-value
    return new_model, new_ivs, round(new_model.pvalues.max(),1)

# %% [markdown]
# Could've used a loop, but seeing which variables were being removed each step was a necessity

# %%
ref1 = refine_model(lr_model,workingivs, .9)
ref2 = refine_model(ref1[0], ref1[1],ref1[2]-.1)
ref3 = refine_model(ref2[0], ref2[1],ref2[2]-.1)
ref4 = refine_model(ref3[0], ref3[1],ref3[2]-.1)
ref5 = refine_model(ref4[0], ref4[1],ref4[2]-.1)
ref6 = refine_model(ref5[0], ref5[1], ref5[2]-.1)
ref7 = refine_model(ref6[0], ref6[1], ref6[2]-.1)
ref8 = refine_model(ref7[0], ref7[1], ref7[2]-.1)
ref9 = refine_model(ref8[0], ref8[1], ref8[2]-.1)
ref10 = refine_model(ref9[0], ref9[1], ref9[2]-.1)
refa = refine_model(ref10[0], ref10[1], ref10[2]-.1)
refb = refine_model(refa[0], refa[1], .09)
refc = refine_model(refb[0], refb[1], .09)
final_model = refine_model(refc[0], refc[1], .08)
# Out:
# 76
# 71
# 68
# 66
# 63
# 62
# 58
# 57
# 55
# 54
# 48
# 46
# 42
# 41

# %% [markdown]
# ## The Final Model

# %%
final_model[0].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                
# hum_misty_spring         3411.3984    959.723      3.555      0.000    1527.071    5295.726
# hum_misty_workingday     1436.8889    534.038      2.691      0.007     388.355    2485.422
# misty_spring_workingday -4859.3324   1006.520     -4.828      0.000   -6835.542   -2883.123
# misty_summer_workingday  -746.1911    260.078     -2.869      0.004   -1256.830    -235.552
# misty_temp_workingday    3292.0771    729.481      4.513      0.000    1859.808    4724.347
# spring_temp_workingday  -3729.7493    976.002     -3.821      0.000   -5646.040   -1813.458
# ==============================================================================
# Omnibus:                      147.976   Durbin-Watson:                   1.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              399.636
# Skew:                          -1.020   Prob(JB):                     1.66e-87
# Kurtosis:                       5.996   Cond. No.                     1.27e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.34e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Final model predictions vs actual counts

# %% [markdown]
# The final_model predicts the residual errors of the original simple linear regression model against original dataset. To imporove prediction of the simple linsear regression, adding the predicted errors from final_model to the predictions of the simple linear regression should bring a closer estimate to the actual count.

# %%
# Visualizing our predictions vs. actual values
fig, ax = plt.subplots(1,2, figsize=(15,5))
plt.style.use('ggplot')

ax[0].scatter(df['instant'], df['predictions'] + final_model[0].predict(final_df))
ax[0].set_title('Model Predicted Bike Count')
ax[0].set_xlabel('Days')
ax[0].set_ylabel('Bike Count')

ax[1].scatter(df['instant'], df.cnt)
ax[1].set_title('Actual Bike Count')
ax[1].set_xlabel('Days')
ax[1].set_ylabel('Bike Count')

plt.savefig('model_vs_actual.png')
plt.show()

# %% [markdown]
# ### Checking the correlation between each of the variables in the final dataframe

# %%
final_df.corr()
# Out:
#                             clear      fall   holiday       hum     misty  \
# clear                    1.000000  0.018488 -0.019148  0.494804 -0.941694
# fall                     0.018488  1.000000  0.053010  0.199154 -0.051365
# holiday                 -0.019148  0.053010  1.000000 -0.015554  0.028600
# hum                      0.494804  0.199154 -0.015554  1.000000 -0.574041
# misty                   -0.941694 -0.051365  0.028600 -0.574041  1.000000
# spring                   0.051627 -0.333323 -0.024408 -0.021851 -0.043897
# summer                  -0.128409 -0.333323 -0.062158 -0.095745  0.152617
# temp                    -0.098043 -0.015691 -0.028629  0.127981  0.115691
# workingday               0.050798 -0.018585 -0.252948  0.022734 -0.058029
# predictions             -0.006176  0.286811  0.016505  0.012948  0.018472
# resids                  -0.222930 -0.009237 -0.103290 -0.134649  0.308814
# 1                             NaN       NaN       NaN       NaN       NaN
# clear_fall               0.433489  0.539883  0.004605  0.258625 -0.408214
# clear_holiday            0.127301  0.018001  0.528956  0.026679 -0.119878
# clear_hum                0.983257  0.029939 -0.026807  0.568130 -0.925927
# clear_spring             0.455410 -0.186995 -0.056048  0.264291 -0.428856
# clear_summer             0.349849 -0.143651 -0.008249  0.140416 -0.329451
# clear_temp               0.916638  0.052265 -0.026611  0.492474 -0.863193
# clear_workingday         0.791132  0.037852 -0.097367  0.363462 -0.745005
# fall_holiday            -0.019657  0.183326  0.611632  0.029783  0.025298
# fall_hum                 0.061010  0.977596  0.049831  0.287895 -0.114590
# fall_misty              -0.296362  0.721763  0.067705 -0.040675  0.314712
# fall_temp                0.036372  0.960662  0.048465  0.242448 -0.069168
# fall_workingday          0.062744  0.776302 -0.076713  0.206761 -0.105120
# spring_temp_workingday  -1.332094e-01  ...        -0.252421
# summer_temp_workingday   3.385083e-02  ...         0.778438
#
#                          hum_summer_workingday  hum_temp_workingday  \
# clear                                -0.076249             0.110776
# fall                                 -0.262284             0.049577
# holiday                              -0.078615            -0.201987
# hum                                  -0.034939             0.303365
# misty                                 0.100888            -0.131204
# spring                               -0.265174            -0.021787
# summer                                0.786875             0.263788
# temp                                  0.550009             0.462805
# workingday                            0.310795             0.798532
# predictions                           0.037464             0.060192
# resids                                0.331737             0.280127
# 1                                          NaN                  NaN
# clear_fall                           -0.141603             0.131693
# clear_holiday                        -0.041584            -0.106842
# clear_hum                            -0.082552             0.128844
# clear_spring                         -0.148763             0.051974
# clear_summer                          0.388941             0.146565
# clear_temp                            0.040725             0.219789
# clear_workingday                      0.018025             0.384892
# fall_holiday                         -0.048083            -0.123542
# fall_hum                             -0.256407             0.102505
# fall_misty                           -0.189307            -0.090027
# fall_temp                            -0.251966             0.106507
# fall_workingday                      -0.203611             0.316981
# holiday_hum                          -0.077309            -0.198632
# holiday_misty                        -0.066162            -0.169992
# holiday_spring                       -0.033906            -0.087116
# holiday_summer                       -0.023942            -0.061516
# holiday_temp                         -0.072201            -0.185509
# hum_misty                             0.120231            -0.048567
# ...                                        ...                  ...
# fall_hum_temp                        -0.242127             0.152477
# fall_hum_workingday                  -0.199616             0.352431
# fall_misty_temp                      -0.182219            -0.051786
# fall_misty_workingday                -0.140387             0.138527
# fall_temp_workingday                 -0.196884             0.366425
# holiday_hum_misty                    -0.064950            -0.166878
# holiday_hum_spring                   -0.033804            -0.086853
# holiday_hum_summer                   -0.023858            -0.061298
# holiday_hum_temp                     -0.069685            -0.179042
# holiday_misty_spring                 -0.033906            -0.087116
# holiday_misty_summer                 -0.016918            -0.043468
# holiday_misty_temp                   -0.061331            -0.157578
# holiday_spring_temp                  -0.033377            -0.085757
# holiday_summer_temp                  -0.023922            -0.061463
# hum_misty_spring                     -0.185851            -0.014867
# hum_misty_summer                      0.649702             0.225108
# hum_misty_temp                        0.325887             0.134708
# hum_misty_workingday                  0.308675             0.438756
# hum_spring_temp                      -0.241076             0.067968
# hum_spring_workingday                -0.202361             0.263605
# hum_summer_temp                       0.791783             0.281380
# hum_summer_workingday                 1.000000             0.547185
# hum_temp_workingday                   0.547185             1.000000
# misty_spring_temp                    -0.185479            -0.021238
# misty_spring_workingday              -0.156858             0.107125
# misty_summer_temp                     0.632112             0.209530
# misty_summer_workingday               0.796790             0.418034
# misty_temp_workingday                 0.506617             0.518496
# spring_temp_workingday               -0.202819             0.265206
# summer_temp_workingday                0.975209             0.529479
#
#                          misty_spring_temp  misty_spring_workingday  \
# clear                            -0.290370                -0.245563
# fall                             -0.233147                -0.197170
# holiday                           0.043456                -0.059098
# hum                              -0.180060                -0.204550
# misty                             0.308349                 0.260768
# spring                            0.699463                 0.591529
# summer                           -0.235717                -0.199343
# temp                              0.077415                -0.009784
# workingday                        0.004634                 0.233639
# predictions                      -0.092970                -0.094580
# resids                            0.270376                 0.176767
# 1                                      NaN                      NaN
# clear_fall                       -0.125872                -0.106449
# clear_holiday                    -0.036964                -0.031260
# clear_hum                        -0.285509                -0.241452
# clear_spring                     -0.132237                -0.111832
# clear_summer                     -0.101586                -0.085910
# clear_temp                       -0.266165                -0.225093
# clear_workingday                 -0.229721                -0.194273
# fall_holiday                     -0.042742                -0.036146
# fall_hum                         -0.227924                -0.192753
# fall_misty                       -0.168277                -0.142310
# fall_temp                        -0.223976                -0.189414
# fall_workingday                  -0.180993                -0.153064
# holiday_hum                       0.048793                -0.058117
# holiday_misty                     0.074727                -0.049737
# holiday_spring                    0.226491                -0.025489
# holiday_summer                   -0.021283                -0.017999
# holiday_temp                      0.083441                -0.054277
# hum_misty                         0.291437                 0.220555
# ...                                    ...                      ...
# fall_hum_temp                    -0.215229                -0.182017
# fall_hum_workingday              -0.177442                -0.150061
# fall_misty_temp                  -0.161977                -0.136982
# fall_misty_workingday            -0.124791                -0.105535
# fall_temp_workingday             -0.175013                -0.148007
# holiday_hum_misty                 0.085566                -0.048826
# holiday_hum_spring                0.225640                -0.025412
# holiday_hum_summer               -0.021207                -0.017935
# holiday_hum_temp                  0.082741                -0.052385
# holiday_misty_spring              0.226491                -0.025489
# holiday_misty_summer             -0.015039                -0.012718
# holiday_misty_temp                0.115285                -0.046105
# holiday_spring_temp               0.230985                -0.025091
# holiday_summer_temp              -0.021265                -0.017983
# hum_misty_spring                  0.972511                 0.785568
# hum_misty_summer                 -0.194572                -0.164548
# hum_misty_temp                    0.278581                 0.171800
# hum_misty_workingday              0.209102                 0.361070
# hum_spring_temp                   0.639172                 0.463562
# hum_spring_workingday             0.468648                 0.615895
# hum_summer_temp                  -0.230841                -0.195220
# hum_summer_workingday            -0.185479                -0.156858
# hum_temp_workingday              -0.021238                 0.107125
# misty_spring_temp                 1.000000                 0.771183
# misty_spring_workingday           0.771183                 1.000000
# misty_summer_temp                -0.196938                -0.166549
# misty_summer_workingday          -0.162709                -0.137602
# misty_temp_workingday             0.199631                 0.326818
# spring_temp_workingday            0.582383                 0.727790
# summer_temp_workingday           -0.188212                -0.159169
#
#                          misty_summer_temp  misty_summer_workingday  \
# clear                            -0.346839                -0.286557
# fall                             -0.278488                -0.230085
# holiday                          -0.060882                -0.068964
# hum                              -0.194359                -0.162573
# misty                             0.368314                 0.304299
# spring                           -0.281557                -0.232620
# summer                            0.835488                 0.690276
# temp                              0.619277                 0.496155
# workingday                        0.037440                 0.272641
# predictions                       0.028827                 0.021784
# resids                            0.383211                 0.335787
# 1                                      NaN                      NaN
# clear_fall                       -0.150351                -0.124219
# clear_holiday                    -0.044153                -0.036479
# clear_hum                        -0.341032                -0.281759
# clear_spring                     -0.157954                -0.130501
# clear_summer                     -0.121341                -0.100252
# clear_temp                       -0.317926                -0.262669
# clear_workingday                 -0.274396                -0.226704
# fall_holiday                     -0.051054                -0.042181
# fall_hum                         -0.272248                -0.224930
# fall_misty                       -0.201002                -0.166067
# fall_temp                        -0.267533                -0.221034
# fall_workingday                  -0.216191                -0.178616
# holiday_hum                      -0.062616                -0.067818
# holiday_misty                    -0.043634                -0.058040
# holiday_spring                   -0.036001                -0.029744
# holiday_summer                    0.046815                -0.021003
# holiday_temp                     -0.041453                -0.063338
# hum_misty                         0.358382                 0.295105
# ...                                    ...                      ...
# fall_hum_temp                    -0.257085                -0.212402
# fall_hum_workingday              -0.211949                -0.175111
# fall_misty_temp                  -0.193476                -0.159849
# fall_misty_workingday            -0.149060                -0.123152
# fall_temp_workingday             -0.209048                -0.172714
# holiday_hum_misty                -0.045221                -0.056977
# holiday_hum_spring               -0.035892                -0.029654
# holiday_hum_summer                0.040583                -0.020929
# holiday_hum_temp                 -0.045320                -0.061130
# holiday_misty_spring             -0.036001                -0.029744
# holiday_misty_summer              0.084124                -0.014841
# holiday_misty_temp               -0.024621                -0.053802
# holiday_spring_temp              -0.035439                -0.029280
# holiday_summer_temp               0.049751                -0.020985
# hum_misty_spring                 -0.197333                -0.163035
# hum_misty_summer                  0.979560                 0.808066
# hum_misty_temp                    0.625708                 0.507405
# hum_misty_workingday              0.287529                 0.458745
# hum_spring_temp                  -0.255970                -0.211481
# hum_spring_workingday            -0.214863                -0.177518
# hum_summer_temp                   0.778602                 0.634425
# hum_summer_workingday             0.632112                 0.796790
# hum_temp_workingday               0.209530                 0.418034
# misty_spring_temp                -0.196938                -0.162709
# misty_spring_workingday          -0.166549                -0.137602
# misty_summer_temp                 1.000000                 0.816293
# misty_summer_workingday           0.816293                 1.000000
# misty_temp_workingday             0.517268                 0.707593
# spring_temp_workingday           -0.215349                -0.177920
# summer_temp_workingday            0.695816                 0.864570
#
#                          misty_temp_workingday  spring_temp_workingday  \
# clear                                -0.550390                0.039473
# fall                                 -0.104752               -0.254943
# holiday                              -0.132459               -0.076415
# hum                                  -0.272927               -0.003878
# misty                                 0.584468               -0.023297
# spring                               -0.028613                0.764852
# summer                                0.361140               -0.257752
# temp                                  0.394271                0.048955
# workingday                            0.523662                0.302097
# predictions                           0.055078               -0.133209
# resids                                0.417097                0.179500
# 1                                          NaN                     NaN
# clear_fall                           -0.238588               -0.137639
# clear_holiday                        -0.070065               -0.040420
# clear_hum                            -0.541175                0.043220
# clear_spring                         -0.250653                0.429061
# clear_summer                         -0.192553               -0.111083
# clear_temp                           -0.504508                0.064619
# clear_workingday                     -0.435431                0.142922
# fall_holiday                         -0.081016               -0.046738
# fall_hum                             -0.126255               -0.249231
# fall_misty                            0.092699               -0.184009
# fall_temp                            -0.085944               -0.244914
# fall_workingday                       0.048474               -0.197913
# holiday_hum                          -0.130259               -0.075145
# holiday_misty                        -0.111478               -0.064311
# holiday_spring                       -0.057129               -0.032957
# holiday_summer                       -0.040341               -0.023272
# holiday_temp                         -0.121653               -0.070181
# hum_misty                             0.586301               -0.024783
# ...                                        ...                     ...
# fall_hum_temp                        -0.107900               -0.235350
# fall_hum_workingday                   0.011208               -0.194030
# fall_misty_temp                       0.119689               -0.177119
# fall_misty_workingday                 0.281957               -0.136457
# fall_temp_workingday                  0.060039               -0.191374
# holiday_hum_misty                    -0.109436               -0.063133
# holiday_hum_spring                   -0.056956               -0.032858
# holiday_hum_summer                   -0.040198               -0.023190
# holiday_hum_temp                     -0.117413               -0.067734
# holiday_misty_spring                 -0.057129               -0.032957
# holiday_misty_summer                 -0.028506               -0.016445
# holiday_misty_temp                   -0.103337               -0.059614
# holiday_spring_temp                  -0.056238               -0.032443
# holiday_summer_temp                  -0.040306               -0.023252
# hum_misty_spring                      0.194039                0.574626
# hum_misty_summer                      0.507118               -0.212762
# hum_misty_temp                        0.676659               -0.007755
# hum_misty_workingday                  0.900434                0.159635
# hum_spring_temp                      -0.032621                0.759520
# hum_spring_workingday                 0.080020                0.948945
# hum_summer_temp                       0.322342               -0.252421
# hum_summer_workingday                 0.506617               -0.202819
# hum_temp_workingday                   0.518496                0.265206
# misty_spring_temp                     0.199631                0.582383
# misty_spring_workingday               0.326818                0.727790
# misty_summer_temp                     0.517268               -0.215349
# misty_summer_workingday               0.707593               -0.177920
# misty_temp_workingday                 1.000000                0.153342
# spring_temp_workingday                0.153342                1.000000
# summer_temp_workingday                0.568761               -0.205807
#
#                          summer_temp_workingday
# clear                                 -0.118267
# fall                                  -0.266148
# holiday                               -0.079773
# hum                                   -0.100267
# misty                                  0.142549
# spring                                -0.269081
# summer                                 0.798467
# temp                                   0.573800
# workingday                             0.315374
# predictions                            0.033851
# resids                                 0.346874
# 1                                           NaN
# clear_fall                            -0.143689
# clear_holiday                         -0.042196
# clear_hum                             -0.125903
# clear_spring                          -0.150955
# clear_summer                           0.312489
# clear_temp                            -0.010988
# clear_workingday                      -0.026858
# fall_holiday                          -0.048792
# fall_hum                              -0.260185
# fall_misty                            -0.192096
# fall_temp                             -0.255678
# fall_workingday                       -0.206611
# holiday_hum                           -0.078448
# holiday_misty                         -0.067137
# holiday_spring                        -0.034406
# holiday_summer                        -0.024295
# holiday_temp                          -0.073265
# hum_misty                              0.141206
# ...                                         ...
# fall_hum_temp                         -0.245694
# fall_hum_workingday                   -0.202557
# fall_misty_temp                       -0.184903
# fall_misty_workingday                 -0.142455
# fall_temp_workingday                  -0.199785
# holiday_hum_misty                     -0.065907
# holiday_hum_spring                    -0.034302
# holiday_hum_summer                    -0.024209
# holiday_hum_temp                      -0.070711
# holiday_misty_spring                  -0.034406
# holiday_misty_summer                  -0.017167
# holiday_misty_temp                    -0.062234
# holiday_spring_temp                   -0.033869
# holiday_summer_temp                   -0.024274
# hum_misty_spring                      -0.188589
# hum_misty_summer                       0.683388
# hum_misty_temp                         0.358345
# hum_misty_workingday                   0.332257
# hum_spring_temp                       -0.244628
# hum_spring_workingday                 -0.205342
# hum_summer_temp                        0.778438
# hum_summer_workingday                  0.975209
# hum_temp_workingday                    0.529479
# misty_spring_temp                     -0.188212
# misty_spring_workingday               -0.159169
# misty_summer_temp                      0.695816
# misty_summer_workingday                0.864570
# misty_temp_workingday                  0.568761
# spring_temp_workingday                -0.205807
# summer_temp_workingday                 1.000000
#
# [93 rows x 93 columns]

# %% [markdown]
# ### Checking the residuals of the final model

# %%
def checkresiduals(df, target, sm_model):
    # checking for our model - Homoscedasticity,  Independence of residuals
    pred_val = sm_model.fittedvalues.copy()
    true_val = df[target].values.copy()
    residual = true_val - pred_val

    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    ax1.hist(residual, density=True, bins=30)
    ax2.scatter(df[target],residual)
    ax2.set_title('Residual Scatterplot')
    plt.show()

# %%
checkresiduals(df, 'resids', final_model[0])
